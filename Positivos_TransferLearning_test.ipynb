# %%
"""
Indentifying images with and without animals via classification.Images with animals
are labeled and "positive", images without are labeled "negative".

Based on: 
    - https://medium.com/@1297rohit/transfer-learning-from-scratch-using-keras-339834b153b9
    - Uses Transfer Learning
    - Based on a VGG (pre trained) model
    
@Author: D. Barros
@Version: 1.0
"""

import os

path = "C:/Users/DBarros/Documents/SAFArI/Machine Learning tryouts/Datasets/Biota01 - positivo"
#path = "M:\Datasets\Biota01 - positivos"

os.chdir(path)
print(os.getcwd())
# Out:
# C:\Users\DBarros\Documents\SAFArI\Machine Learning tryouts\Datasets\Biota01 - positivo

# %%
import keras
from keras.models import Model
from keras.layers import Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
batch_size = 32
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="train", batch_size=batch_size, target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="test", batch_size=batch_size, target_size=(224,224))
# Out:
# Found 4192 images belonging to 2 classes.
# Found 480 images belonging to 2 classes.

# %%
from keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=True)

# %%
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Setting the 19 layers in the model to be static as I do not want them to be trained again. This will be changed.
for layers in (vggmodel.layers)[:19]:
    print(layers)
    layers.trainable = False
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x00000254527BE220>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BA04760>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BA04F70>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002545BA04BE0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC23490>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC2B8B0>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002545BAD3DF0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC40CA0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC40D60>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC4ACA0>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002545BC34CD0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC5A2E0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545BC340D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545B88B2E0>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x00000254559D1460>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545595ED60>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002545598EA90>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025459CCB730>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002545597FFD0>

# %%
#Adjusting the pre trained VGG model. Pre trained model is trained for 1000 classes. I only want 2 classes.
X= vggmodel.layers[-2].output
predictions = Dense(2, activation="softmax")(X)
model_final = Model(inputs = vggmodel.input, outputs = predictions)

# %%
#Compiling the new model
model_final.compile(loss = "categorical_crossentropy",
                    optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 119,554,050
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Early stoping allows for the model to stop if accuracy hasn't improved in "patience" epochs.
#Model chekpoint allows for saving of the best model

from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

model_final.fit_generator(generator= traindata,
                          steps_per_epoch= traindata.samples/batch_size,
                          epochs= 5,
                          validation_data= testdata,
                          validation_steps=testdata.samples/batch_size,
                          callbacks=[checkpoint,early])

model_final.save_weights("vgg16_1.h5")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-14-661aa236c6d2>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1982 - accuracy: 0.9122
# Epoch 00001: val_accuracy improved from -inf to 0.83499, saving model to vgg16_1.h5
# 7717/7716 [==============================] - 46166s 6s/step - loss: 0.1982 - accuracy: 0.9122 - val_loss: 0.3712 - val_accuracy: 0.8350
# Epoch 2/5
# 5440/7716 [====================>.........] - ETA: 3:39:11 - loss: 0.1483 - accuracy: 0.9351

# %%
# load and iterate predictions
predict_data = ImageDataGenerator()
predictdata = predict_data.flow_from_directory(directory="predict", target_size=(224,224))
# Out:
# Found 78 images belonging to 1 classes.

# %%
#Make some predictions
model = keras.models.load_model('./vgg16_1.h5')
pred=model_final.predict(predictdata)
print("done")
# Out:
# done

# %%
import numpy as np
import pandas as pd
predicted_class_indices=np.argmax(pred,axis=1)

labels = (traindata.class_indices)
labels = dict((v,k) for k,v in labels.items())
preds= [labels[k] for k in predicted_class_indices]
probs = [float(max(i)) for i in pred]

filenames=predictdata.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":preds,
                      "Probability":probs,
                      })

# %%
pd.options.display.max_rows = 99
results
# Out:
#                                       Filename Predictions  Probability
# 0                     predictions\11300077.JPG   negativos     0.672173
# 1                     predictions\11300078.JPG   negativos     0.912160
# 2                     predictions\11300079.JPG   negativos     0.817577
# 3                     predictions\11300080.JPG   negativos     0.701961
# 4                     predictions\11300081.JPG   positivos     0.548144
# 5                     predictions\11300082.JPG   negativos     0.807499
# 6                     predictions\11300083.JPG   negativos     0.620843
# 7                     predictions\11300084.JPG   negativos     0.818332
# 8                     predictions\11300085.JPG   negativos     0.691047
# 9                     predictions\11300086.JPG   negativos     0.699187
# 10                    predictions\11300087.JPG   negativos     0.877087
# 11                    predictions\11300088.JPG   positivos     0.981710
# 12        predictions\Aegypius monachus_01.JPG   positivos     0.535258
# 13        predictions\Aegypius monachus_02.JPG   negativos     0.753450
# 14        predictions\Aegypius monachus_03.JPG   positivos     0.880429
# 15        predictions\Aegypius monachus_04.JPG   negativos     0.582529
# 16        predictions\Aegypius monachus_05.JPG   negativos     0.901038
# 17        predictions\Aegypius monachus_06.JPG   negativos     0.786299
# 18        predictions\Aegypius monachus_07.JPG   positivos     0.502822
# 19        predictions\Aegypius monachus_09.JPG   negativos     0.570859
# 20        predictions\Aegypius monachus_13.JPG   positivos     0.830482
# 21        predictions\Aegypius monachus_14.JPG   negativos     0.857022
# 22        predictions\Aegypius monachus_18.JPG   negativos     0.710337
# 23        predictions\Aegypius monachus_22.JPG   negativos     0.932778
# 24            predictions\Alectoris rufa_1.JPG   positivos     0.785205
# 25           predictions\Alectoris rufa_10.JPG   negativos     0.627385
# 26           predictions\Alectoris rufa_11.JPG   positivos     0.566537
# 27           predictions\Alectoris rufa_12.JPG   positivos     0.944841
# 28            predictions\Alectoris rufa_2.JPG   negativos     0.631497
# 29            predictions\Alectoris rufa_3.JPG   negativos     0.944086
# 30            predictions\Alectoris rufa_4.JPG   negativos     0.957836
# 31            predictions\Alectoris rufa_5.JPG   negativos     0.948737
# 32            predictions\Alectoris rufa_6.JPG   negativos     0.557315
# 33            predictions\Alectoris rufa_7.JPG   positivos     0.520131
# 34            predictions\Alectoris rufa_8.JPG   negativos     0.508589
# 35            predictions\Alectoris rufa_9.JPG   negativos     0.980539
# 36              predictions\Bos tauros_001.JPG   negativos     0.871464
# 37              predictions\Bos tauros_002.JPG   positivos     0.640359
# 38              predictions\Bos tauros_003.JPG   negativos     0.701683
# 39              predictions\Bos tauros_004.JPG   negativos     0.907731
# 40              predictions\Bos tauros_005.JPG   negativos     0.787986
# 41              predictions\Bos tauros_006.JPG   positivos     0.505300
# 42              predictions\Bos tauros_007.JPG   positivos     0.802385
# 43              predictions\Bos tauros_008.JPG   negativos     0.868149
# 44              predictions\Bos tauros_009.JPG   positivos     0.723761
# 45              predictions\Bos tauros_010.JPG   negativos     0.943711
# 46              predictions\Bos tauros_011.JPG   negativos     0.875981
# 47              predictions\Bos tauros_012.JPG   negativos     0.638258
# 48              predictions\Bos tauros_013.JPG   negativos     0.959786
# 49              predictions\Bos tauros_014.JPG   negativos     0.920281
# 50              predictions\Bos tauros_015.JPG   negativos     0.726917
# 51              predictions\Bos tauros_016.JPG   negativos     0.741115
# 52              predictions\Bos tauros_017.JPG   positivos     0.566014
# 53              predictions\Bos tauros_018.JPG   negativos     0.904015
# 54              predictions\Bos tauros_019.JPG   negativos     0.956560
# 55              predictions\Bos tauros_020.JPG   negativos     0.744923
# 56  predictions\Canis lupus familiaris_114.jpg   negativos     0.950927
# 57  predictions\Canis lupus familiaris_115.jpg   positivos     0.755250
# 58  predictions\Canis lupus familiaris_116.jpg   negativos     0.614427
# 59  predictions\Canis lupus familiaris_117.JPG   positivos     0.788481
# 60  predictions\Canis lupus familiaris_118.JPG   negativos     0.850675
# 61  predictions\Canis lupus familiaris_119.JPG   negativos     0.878419
# 62  predictions\Canis lupus familiaris_120.JPG   negativos     0.847900
# 63  predictions\Canis lupus familiaris_121.JPG   positivos     0.968288
# 64  predictions\Canis lupus familiaris_122.JPG   negativos     0.917501
# 65  predictions\Canis lupus familiaris_123.JPG   negativos     0.881131
# 66  predictions\Canis lupus familiaris_124.JPG   negativos     0.530208
# 67  predictions\Canis lupus familiaris_125.JPG   positivos     0.911769
# 68  predictions\Canis lupus familiaris_126.JPG   negativos     0.781216
# 69  predictions\Canis lupus familiaris_127.JPG   positivos     0.984680
# 70  predictions\Canis lupus familiaris_128.JPG   positivos     0.504303
# 71  predictions\Canis lupus familiaris_129.JPG   negativos     0.969933
# 72  predictions\Canis lupus familiaris_130.JPG   negativos     0.591810
# 73  predictions\Canis lupus familiaris_131.JPG   negativos     0.839990
# 74  predictions\Canis lupus familiaris_132.JPG   negativos     0.585582
# 75  predictions\Canis lupus familiaris_133.JPG   positivos     0.644754
# 76  predictions\Canis lupus familiaris_134.JPG   positivos     0.828356
# 77                    predictions\EK000869.JPG   positivos     0.778273

# %%
# Out:
# Sent

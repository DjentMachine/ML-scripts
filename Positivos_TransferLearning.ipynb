# %%
"""
Indentifying images with and without animals via classification.Images with animals
are labeled and "positive", images without are labeled "negative".

Based on: 
    - https://medium.com/@1297rohit/transfer-learning-from-scratch-using-keras-339834b153b9
    - Uses Transfer Learning
    - Based on a VGG (pre trained) model
    
@Author: D. Barros
@Version: 1.0
"""

import os

path = "C:/Users/DBarros/Documents/SAFArI/Machine Learning tryouts/Datasets/Biota01 - positivo"
#path = "M:\Datasets\Biota01 - positivos"

os.chdir(path)
print(os.getcwd())
# Out:
# C:\Users\DBarros\Documents\SAFArI\Machine Learning tryouts\Datasets\Biota01 - positivo

# %%
import keras
from keras.models import Model
from keras.layers import Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
batch_size = 32
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="train", batch_size=batch_size, target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="test", batch_size=batch_size, target_size=(224,224))
# Out:
# Found 4192 images belonging to 2 classes.
# Found 480 images belonging to 2 classes.

# %%
from keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=True)

# %%
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Setting the 19 layers in the model to be static as I do not want them to be trained again. This will be changed.
for layers in (vggmodel.layers)[:19]:
    print(layers)
    layers.trainable = False
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x0000027949DE1F70>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000027950830760>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000027950830E50>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000027953628370>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794DB33310>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794DB33970>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000027953628340>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794DB467F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794DB463D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794DB4E310>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002794D634F70>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D6394F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D63E1C0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D644F10>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002794D64D6D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D655B50>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D65A9A0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002794D661940>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002794D64D550>

# %%
#Adjusting the pre trained VGG model. Pre trained model is trained for 1000 classes. I only want 2 classes.
X= vggmodel.layers[-2].output
predictions = Dense(2, activation="softmax")(X)
model_final = Model(inputs = vggmodel.input, outputs = predictions)

# %%
#Compiling the new model
model_final.compile(loss = "categorical_crossentropy",
                    optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 119,554,050
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Early stoping allows for the model to stop if accuracy hasn't improved in "patience" epochs.
#Model chekpoint allows for saving of the best model

from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

model_final.fit_generator(generator= traindata,
                          steps_per_epoch= traindata.samples/batch_size,
                          epochs= 5,
                          validation_data= testdata,
                          validation_steps=testdata.samples/batch_size,
                          callbacks=[checkpoint,early])

model_final.save_weights("vgg16_1.h5")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-14-661aa236c6d2>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1982 - accuracy: 0.9122
# Epoch 00001: val_accuracy improved from -inf to 0.83499, saving model to vgg16_1.h5
# 7717/7716 [==============================] - 46166s 6s/step - loss: 0.1982 - accuracy: 0.9122 - val_loss: 0.3712 - val_accuracy: 0.8350
# Epoch 2/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1456 - accuracy: 0.9365
# Epoch 00002: val_accuracy improved from 0.83499 to 0.88723, saving model to vgg16_1.h5
# 7717/7716 [==============================] - 46245s 6s/step - loss: 0.1456 - accuracy: 0.9365 - val_loss: 0.2587 - val_accuracy: 0.8872
# Epoch 3/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1271 - accuracy: 0.9459
# Epoch 00003: val_accuracy did not improve from 0.88723
# 7717/7716 [==============================] - 46496s 6s/step - loss: 0.1271 - accuracy: 0.9459 - val_loss: 0.3004 - val_accuracy: 0.8702
# Epoch 4/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1157 - accuracy: 0.9509
# Epoch 00004: val_accuracy improved from 0.88723 to 0.89411, saving model to vgg16_1.h5
# 7717/7716 [==============================] - 46079s 6s/step - loss: 0.1157 - accuracy: 0.9509 - val_loss: 0.2453 - val_accuracy: 0.8941
# Epoch 5/5
# 7717/7716 [==============================] - ETA: -5s - loss: 0.1071 - accuracy: 0.9553
# Epoch 00005: val_accuracy improved from 0.89411 to 0.91160, saving model to vgg16_1.h5
# 7717/7716 [==============================] - 46910s 6s/step - loss: 0.1071 - accuracy: 0.9553 - val_loss: 0.2191 - val_accuracy: 0.9116

# %%
# Loading the model which will predict our results
model_final = keras.models.load_model('./vgg16_1.h5')

# %%
# load and iterate predictions
predict_data = ImageDataGenerator()
predictdata = predict_data.flow_from_directory(directory="predict", target_size=(224,224))
# Out:
# Found 78 images belonging to 1 classes.

# %%
#Make some predictions
pred=model_final.predict(predictdata)
print("done")
# Out:
# done

# %%
import numpy as np
import pandas as pd
predicted_class_indices=np.argmax(pred,axis=1)

labels = (traindata.class_indices)
labels = dict((v,k) for k,v in labels.items())
preds= [labels[k] for k in predicted_class_indices]
probs = [float(max(i)) for i in pred]

filenames=predictdata.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":preds,
                      "Probability":probs,
                      })

# %%
pd.options.display.max_rows = 99
results
# Out:
#                                       Filename Predictions  Probability
# 0                     predictions\11300077.JPG   positivos     0.999677
# 1                     predictions\11300078.JPG   negativos     0.999466
# 2                     predictions\11300079.JPG   positivos     0.999373
# 3                     predictions\11300080.JPG   positivos     0.999940
# 4                     predictions\11300081.JPG   positivos     1.000000
# 5                     predictions\11300082.JPG   positivos     0.999998
# 6                     predictions\11300083.JPG   positivos     0.999903
# 7                     predictions\11300084.JPG   negativos     0.988383
# 8                     predictions\11300085.JPG   positivos     0.999994
# 9                     predictions\11300086.JPG   positivos     0.979048
# 10                    predictions\11300087.JPG   positivos     0.999826
# 11                    predictions\11300088.JPG   negativos     0.999301
# 12        predictions\Aegypius monachus_01.JPG   positivos     0.999965
# 13        predictions\Aegypius monachus_02.JPG   positivos     0.999999
# 14        predictions\Aegypius monachus_03.JPG   positivos     1.000000
# 15        predictions\Aegypius monachus_04.JPG   positivos     0.988943
# 16        predictions\Aegypius monachus_05.JPG   positivos     0.999969
# 17        predictions\Aegypius monachus_06.JPG   positivos     0.997798
# 18        predictions\Aegypius monachus_07.JPG   positivos     0.999949
# 19        predictions\Aegypius monachus_09.JPG   positivos     0.999979
# 20        predictions\Aegypius monachus_13.JPG   negativos     0.999701
# 21        predictions\Aegypius monachus_14.JPG   positivos     0.999994
# 22        predictions\Aegypius monachus_18.JPG   positivos     0.999879
# 23        predictions\Aegypius monachus_22.JPG   positivos     0.999999
# 24            predictions\Alectoris rufa_1.JPG   negativos     0.994374
# 25           predictions\Alectoris rufa_10.JPG   positivos     0.999903
# 26           predictions\Alectoris rufa_11.JPG   positivos     0.999999
# 27           predictions\Alectoris rufa_12.JPG   negativos     0.992917
# 28            predictions\Alectoris rufa_2.JPG   positivos     0.999992
# 29            predictions\Alectoris rufa_3.JPG   negativos     0.999197
# 30            predictions\Alectoris rufa_4.JPG   positivos     0.999604
# 31            predictions\Alectoris rufa_5.JPG   positivos     0.999562
# 32            predictions\Alectoris rufa_6.JPG   positivos     0.999918
# 33            predictions\Alectoris rufa_7.JPG   negativos     0.998060
# 34            predictions\Alectoris rufa_8.JPG   positivos     0.998653
# 35            predictions\Alectoris rufa_9.JPG   positivos     0.999665
# 36              predictions\Bos tauros_001.JPG   positivos     0.999808
# 37              predictions\Bos tauros_002.JPG   positivos     0.999954
# 38              predictions\Bos tauros_003.JPG   positivos     0.999967
# 39              predictions\Bos tauros_004.JPG   positivos     0.989545
# 40              predictions\Bos tauros_005.JPG   negativos     0.996023
# 41              predictions\Bos tauros_006.JPG   positivos     0.999566
# 42              predictions\Bos tauros_007.JPG   negativos     0.998442
# 43              predictions\Bos tauros_008.JPG   positivos     0.999997
# 44              predictions\Bos tauros_009.JPG   positivos     0.999918
# 45              predictions\Bos tauros_010.JPG   positivos     0.999853
# 46              predictions\Bos tauros_011.JPG   positivos     0.999993
# 47              predictions\Bos tauros_012.JPG   negativos     0.998880
# 48              predictions\Bos tauros_013.JPG   positivos     0.999832
# 49              predictions\Bos tauros_014.JPG   positivos     0.999990
# 50              predictions\Bos tauros_015.JPG   positivos     0.999846
# 51              predictions\Bos tauros_016.JPG   positivos     0.999586
# 52              predictions\Bos tauros_017.JPG   positivos     0.998737
# 53              predictions\Bos tauros_018.JPG   positivos     0.999999
# 54              predictions\Bos tauros_019.JPG   positivos     0.999997
# 55              predictions\Bos tauros_020.JPG   positivos     0.999988
# 56  predictions\Canis lupus familiaris_114.jpg   positivos     0.999709
# 57  predictions\Canis lupus familiaris_115.jpg   positivos     1.000000
# 58  predictions\Canis lupus familiaris_116.jpg   positivos     0.992230
# 59  predictions\Canis lupus familiaris_117.JPG   positivos     0.999684
# 60  predictions\Canis lupus familiaris_118.JPG   positivos     0.999916
# 61  predictions\Canis lupus familiaris_119.JPG   positivos     0.999632
# 62  predictions\Canis lupus familiaris_120.JPG   positivos     0.999682
# 63  predictions\Canis lupus familiaris_121.JPG   positivos     0.998659
# 64  predictions\Canis lupus familiaris_122.JPG   positivos     0.999902
# 65  predictions\Canis lupus familiaris_123.JPG   positivos     1.000000
# 66  predictions\Canis lupus familiaris_124.JPG   positivos     0.999559
# 67  predictions\Canis lupus familiaris_125.JPG   positivos     0.999986
# 68  predictions\Canis lupus familiaris_126.JPG   positivos     0.999933
# 69  predictions\Canis lupus familiaris_127.JPG   positivos     0.999601
# 70  predictions\Canis lupus familiaris_128.JPG   positivos     0.999951
# 71  predictions\Canis lupus familiaris_129.JPG   positivos     0.999372
# 72  predictions\Canis lupus familiaris_130.JPG   positivos     0.978772
# 73  predictions\Canis lupus familiaris_131.JPG   negativos     0.998736
# 74  predictions\Canis lupus familiaris_132.JPG   positivos     0.999994
# 75  predictions\Canis lupus familiaris_133.JPG   positivos     0.999686
# 76  predictions\Canis lupus familiaris_134.JPG   positivos     0.999994
# 77                    predictions\EK000869.JPG   positivos     0.999902

# %%
#Saving the results in a csv file
results.to_csv("results.csv",index=False)

# %%
#Saving the results in a jason file
import json
dResults = {}
dResults['results'] = []
for i in range(len(results.Filename)):
    dResults["results"].append({
        "Filename" : results.Filename[i],
        "Predictions" : results.Predictions[i],
        "Probability" : results.Probability[i],
    })

# %%
with open('data.JSON', 'w') as outfile:
    json.dump(dResults, outfile)
